# %%
import pandas as pd
from pycaret.classification import *

df = pd.read_csv('dataset.csv')
cat_features = ["sma_pc_29", "sma_pc_28", "sma_pc_27", "sma_pc_26", "sma_pc_25", "sma_pc_24", "sma_pc_23", "sma_pc_22", "sma_pc_21", "sma_pc_20", "sma_pc_19", "sma_pc_18", "sma_pc_17", "sma_pc_16", "sma_pc_15", "sma_pc_14", "sma_pc_13", "sma_pc_12", "sma_pc_11", "sma_pc_10", "sma_pc_9", "sma_pc_8", "sma_pc_7", "sma_pc_6", "sma_pc_5", "sma_pc_4", "sma_pc_3", "sma_pc_2", "sma_pc_1", "sma_pc_0", "sma_pc_sum"]
experiment = setup(df, target="signal", categorical_features=cat_features)

best_model = compare_models()
# Out:
# ...
# <style type="text/css">
# #T_032f8_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_032f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_032f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_032f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_032f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_032f8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_032f8_row0_col1" class="data row0 col1" >7628</td>
#     </tr>
#     <tr>
#       <th id="T_032f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_032f8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_032f8_row1_col1" class="data row1 col1" >signal</td>
#     </tr>
#     <tr>
#       <th id="T_032f8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
predict_model(best_model, df.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_8eaec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eaec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8eaec_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8eaec_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8eaec_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8eaec_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8eaec_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8eaec_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8eaec_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eaec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8eaec_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
# ...

# %%
save_model(best_model, model_name='dt-model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['idx', 'ts', 'long_runup',
#                                               'long_drawdown', 'short_runup',
#                                               'short_drawdown'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                f...
#                                                                hierarchy=None,
# ...

# %%
model = load_model('dt-model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
model.predict(df.tail())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.predict(df.tail())
#
# File ~/.local/lib/python3.10/site-packages/pycaret/internal/pipeline.py:312, in Pipeline.predict(self, X, **predict_params)
#     308 @available_if(_final_estimator_has("predict"))
#     309 def predict(self, X, **predict_params):
#     310     X, _ = self._memory_full_transform(self, X, None, with_final=False)
# --> 312     y = self.steps[-1][-1].predict(X, **predict_params)
#     313     y = self.inverse_transform(y)
#     315     return y
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:426, in BaseDecisionTree.predict(self, X, check_input)
#     403 """Predict class or regression value for X.
#     404
#     405 For a classification model, the predicted class for each sample in X is
#    (...)
# ...
